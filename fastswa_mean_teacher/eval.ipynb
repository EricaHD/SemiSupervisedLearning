# %%
from model import Model
import argparse
import json
import torch

from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
def load_data(data_dir, batch_size, split):
    """ Method returning a data loader for labeled data """
    transform = transforms.Compose([
        transforms.Resize(32),
        transforms.ToTensor(),
        transforms.Normalize((0.5011, 0.4727, 0.4229), (0.2835, 0.2767, 0.2950))  # RGB means, RGB stds
    ])
    data = datasets.ImageFolder(f'{data_dir}/supervised/{split}', transform=transform)
    data_loader = DataLoader(
        data,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0
    )
    return data_loader

def evaluate(model, data_loader, device, split, top_k=5):
    """ Method returning accuracy@1 and accuracy@top_k """
    print(f'\nEvaluating {split} set...')
    model.eval()
    n_samples = 0.
    n_correct_top_1 = 0
    n_correct_top_k = 0

    for img, target in data_loader:
        img, target = img.to(device), target.to(device)
        batch_size = img.size(0)
        n_samples += batch_size

        # Forward
        output = model(img)[0]

        # Top 1 accuracy
        pred_top_1 = torch.topk(output, k=1, dim=1)[1]
        n_correct_top_1 += pred_top_1.eq(target.view_as(pred_top_1)).int().sum().item()

        # Top k accuracy
        pred_top_k = torch.topk(output, k=top_k, dim=1)[1]
        target_top_k = target.view(-1, 1).expand(batch_size, top_k)
        n_correct_top_k += pred_top_k.eq(target_top_k).int().sum().item()

    # Accuracy
    top_1_acc = n_correct_top_1/n_samples
    top_k_acc = n_correct_top_k/n_samples

    # Log
    print(f'{split} top 1 accuracy: {top_1_acc:.4f}')
    print(f'{split} top {top_k} accuracy: {top_k_acc:.4f}')

# %%
# Set random seed and device
torch.manual_seed(10)
torch.cuda.manual_seed_all(10)
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load pre-trained model
model = Model().to(device) 
print('n parameters: %d' % sum([m.numel() for m in model.parameters()]))
# Out:
# Parameters found in pretrained model:
# 	conv1.weight
# 	layer1.0.conv_a1.weight
# 	layer1.0.bn_a1.weight
# 	layer1.0.bn_a1.bias
# 	layer1.0.bn_a1.running_mean
# 	layer1.0.bn_a1.running_var
# 	layer1.0.bn_a1.num_batches_tracked
# 	layer1.0.conv_a2.weight
# 	layer1.0.bn_a2.weight
# 	layer1.0.bn_a2.bias
# 	layer1.0.bn_a2.running_mean
# 	layer1.0.bn_a2.running_var
# 	layer1.0.bn_a2.num_batches_tracked
# 	layer1.0.conv_b1.weight
# 	layer1.0.bn_b1.weight
# 	layer1.0.bn_b1.bias
# 	layer1.0.bn_b1.running_mean
# 	layer1.0.bn_b1.running_var
# 	layer1.0.bn_b1.num_batches_tracked
# 	layer1.0.conv_b2.weight
# 	layer1.0.bn_b2.weight
# 	layer1.0.bn_b2.bias
# 	layer1.0.bn_b2.running_mean
# 	layer1.0.bn_b2.running_var
# 	layer1.0.bn_b2.num_batches_tracked
# 	layer1.0.downsample.0.weight
# 	layer1.0.downsample.1.weight
# 	layer1.0.downsample.1.bias
# 	layer1.0.downsample.1.running_mean
# 	layer1.0.downsample.1.running_var
# 	layer1.0.downsample.1.num_batches_tracked
# 	layer1.1.conv_a1.weight
# 	layer1.1.bn_a1.weight
# 	layer1.1.bn_a1.bias
# 	layer1.1.bn_a1.running_mean
# 	layer1.1.bn_a1.running_var
# 	layer1.1.bn_a1.num_batches_tracked
# 	layer1.1.conv_a2.weight
# 	layer1.1.bn_a2.weight
# 	layer1.1.bn_a2.bias
# 	layer1.1.bn_a2.running_mean
# 	layer1.1.bn_a2.running_var
# 	layer1.1.bn_a2.num_batches_tracked
# 	layer1.1.conv_b1.weight
# 	layer1.1.bn_b1.weight
# 	layer1.1.bn_b1.bias
# 	layer1.1.bn_b1.running_mean
# 	layer1.1.bn_b1.running_var
# 	layer1.1.bn_b1.num_batches_tracked
# 	layer1.1.conv_b2.weight
# 	layer1.1.bn_b2.weight
# 	layer1.1.bn_b2.bias
# 	layer1.1.bn_b2.running_mean
# 	layer1.1.bn_b2.running_var
# 	layer1.1.bn_b2.num_batches_tracked
# 	layer1.2.conv_a1.weight
# 	layer1.2.bn_a1.weight
# 	layer1.2.bn_a1.bias
# 	layer1.2.bn_a1.running_mean
# 	layer1.2.bn_a1.running_var
# 	layer1.2.bn_a1.num_batches_tracked
# 	layer1.2.conv_a2.weight
# 	layer1.2.bn_a2.weight
# 	layer1.2.bn_a2.bias
# 	layer1.2.bn_a2.running_mean
# 	layer1.2.bn_a2.running_var
# 	layer1.2.bn_a2.num_batches_tracked
# 	layer1.2.conv_b1.weight
# 	layer1.2.bn_b1.weight
# 	layer1.2.bn_b1.bias
# 	layer1.2.bn_b1.running_mean
# 	layer1.2.bn_b1.running_var
# 	layer1.2.bn_b1.num_batches_tracked
# 	layer1.2.conv_b2.weight
# 	layer1.2.bn_b2.weight
# 	layer1.2.bn_b2.bias
# 	layer1.2.bn_b2.running_mean
# 	layer1.2.bn_b2.running_var
# 	layer1.2.bn_b2.num_batches_tracked
# 	layer1.3.conv_a1.weight
# 	layer1.3.bn_a1.weight
# 	layer1.3.bn_a1.bias
# 	layer1.3.bn_a1.running_mean
# 	layer1.3.bn_a1.running_var
# 	layer1.3.bn_a1.num_batches_tracked
# 	layer1.3.conv_a2.weight
# 	layer1.3.bn_a2.weight
# 	layer1.3.bn_a2.bias
# 	layer1.3.bn_a2.running_mean
# 	layer1.3.bn_a2.running_var
# 	layer1.3.bn_a2.num_batches_tracked
# 	layer1.3.conv_b1.weight
# 	layer1.3.bn_b1.weight
# 	layer1.3.bn_b1.bias
# 	layer1.3.bn_b1.running_mean
# 	layer1.3.bn_b1.running_var
# 	layer1.3.bn_b1.num_batches_tracked
# 	layer1.3.conv_b2.weight
# 	layer1.3.bn_b2.weight
# 	layer1.3.bn_b2.bias
# 	layer1.3.bn_b2.running_mean
# 	layer1.3.bn_b2.running_var
# 	layer1.3.bn_b2.num_batches_tracked
# 	layer2.0.conv_a1.weight
# 	layer2.0.bn_a1.weight
# 	layer2.0.bn_a1.bias
# 	layer2.0.bn_a1.running_mean
# 	layer2.0.bn_a1.running_var
# 	layer2.0.bn_a1.num_batches_tracked
# 	layer2.0.conv_a2.weight
# 	layer2.0.bn_a2.weight
# 	layer2.0.bn_a2.bias
# 	layer2.0.bn_a2.running_mean
# 	layer2.0.bn_a2.running_var
# 	layer2.0.bn_a2.num_batches_tracked
# 	layer2.0.conv_b1.weight
# 	layer2.0.bn_b1.weight
# 	layer2.0.bn_b1.bias
# 	layer2.0.bn_b1.running_mean
# 	layer2.0.bn_b1.running_var
# 	layer2.0.bn_b1.num_batches_tracked
# 	layer2.0.conv_b2.weight
# 	layer2.0.bn_b2.weight
# 	layer2.0.bn_b2.bias
# 	layer2.0.bn_b2.running_mean
# 	layer2.0.bn_b2.running_var
# 	layer2.0.bn_b2.num_batches_tracked
# 	layer2.0.downsample.conv.weight
# 	layer2.0.downsample.conv.bias
# 	layer2.0.downsample.bn.weight
# 	layer2.0.downsample.bn.bias
# 	layer2.0.downsample.bn.running_mean
# 	layer2.0.downsample.bn.running_var
# 	layer2.0.downsample.bn.num_batches_tracked
# 	layer2.1.conv_a1.weight
# 	layer2.1.bn_a1.weight
# 	layer2.1.bn_a1.bias
# 	layer2.1.bn_a1.running_mean
# 	layer2.1.bn_a1.running_var
# 	layer2.1.bn_a1.num_batches_tracked
# 	layer2.1.conv_a2.weight
# 	layer2.1.bn_a2.weight
# 	layer2.1.bn_a2.bias
# 	layer2.1.bn_a2.running_mean
# 	layer2.1.bn_a2.running_var
# 	layer2.1.bn_a2.num_batches_tracked
# 	layer2.1.conv_b1.weight
# 	layer2.1.bn_b1.weight
# 	layer2.1.bn_b1.bias
# 	layer2.1.bn_b1.running_mean
# 	layer2.1.bn_b1.running_var
# 	layer2.1.bn_b1.num_batches_tracked
# 	layer2.1.conv_b2.weight
# 	layer2.1.bn_b2.weight
# 	layer2.1.bn_b2.bias
# 	layer2.1.bn_b2.running_mean
# 	layer2.1.bn_b2.running_var
# 	layer2.1.bn_b2.num_batches_tracked
# 	layer2.2.conv_a1.weight
# 	layer2.2.bn_a1.weight
# 	layer2.2.bn_a1.bias
# 	layer2.2.bn_a1.running_mean
# 	layer2.2.bn_a1.running_var
# 	layer2.2.bn_a1.num_batches_tracked
# 	layer2.2.conv_a2.weight
# 	layer2.2.bn_a2.weight
# 	layer2.2.bn_a2.bias
# 	layer2.2.bn_a2.running_mean
# 	layer2.2.bn_a2.running_var
# 	layer2.2.bn_a2.num_batches_tracked
# 	layer2.2.conv_b1.weight
# 	layer2.2.bn_b1.weight
# 	layer2.2.bn_b1.bias
# 	layer2.2.bn_b1.running_mean
# 	layer2.2.bn_b1.running_var
# 	layer2.2.bn_b1.num_batches_tracked
# 	layer2.2.conv_b2.weight
# 	layer2.2.bn_b2.weight
# 	layer2.2.bn_b2.bias
# 	layer2.2.bn_b2.running_mean
# 	layer2.2.bn_b2.running_var
# 	layer2.2.bn_b2.num_batches_tracked
# 	layer2.3.conv_a1.weight
# 	layer2.3.bn_a1.weight
# 	layer2.3.bn_a1.bias
# 	layer2.3.bn_a1.running_mean
# 	layer2.3.bn_a1.running_var
# 	layer2.3.bn_a1.num_batches_tracked
# 	layer2.3.conv_a2.weight
# 	layer2.3.bn_a2.weight
# 	layer2.3.bn_a2.bias
# 	layer2.3.bn_a2.running_mean
# 	layer2.3.bn_a2.running_var
# 	layer2.3.bn_a2.num_batches_tracked
# 	layer2.3.conv_b1.weight
# 	layer2.3.bn_b1.weight
# 	layer2.3.bn_b1.bias
# 	layer2.3.bn_b1.running_mean
# 	layer2.3.bn_b1.running_var
# 	layer2.3.bn_b1.num_batches_tracked
# 	layer2.3.conv_b2.weight
# 	layer2.3.bn_b2.weight
# 	layer2.3.bn_b2.bias
# 	layer2.3.bn_b2.running_mean
# 	layer2.3.bn_b2.running_var
# 	layer2.3.bn_b2.num_batches_tracked
# 	layer3.0.conv_a1.weight
# 	layer3.0.bn_a1.weight
# 	layer3.0.bn_a1.bias
# 	layer3.0.bn_a1.running_mean
# 	layer3.0.bn_a1.running_var
# 	layer3.0.bn_a1.num_batches_tracked
# 	layer3.0.conv_a2.weight
# 	layer3.0.bn_a2.weight
# 	layer3.0.bn_a2.bias
# 	layer3.0.bn_a2.running_mean
# 	layer3.0.bn_a2.running_var
# 	layer3.0.bn_a2.num_batches_tracked
# 	layer3.0.conv_b1.weight
# 	layer3.0.bn_b1.weight
# 	layer3.0.bn_b1.bias
# 	layer3.0.bn_b1.running_mean
# 	layer3.0.bn_b1.running_var
# 	layer3.0.bn_b1.num_batches_tracked
# 	layer3.0.conv_b2.weight
# 	layer3.0.bn_b2.weight
# 	layer3.0.bn_b2.bias
# 	layer3.0.bn_b2.running_mean
# 	layer3.0.bn_b2.running_var
# 	layer3.0.bn_b2.num_batches_tracked
# 	layer3.0.downsample.conv.weight
# 	layer3.0.downsample.conv.bias
# 	layer3.0.downsample.bn.weight
# 	layer3.0.downsample.bn.bias
# 	layer3.0.downsample.bn.running_mean
# 	layer3.0.downsample.bn.running_var
# 	layer3.0.downsample.bn.num_batches_tracked
# 	layer3.1.conv_a1.weight
# 	layer3.1.bn_a1.weight
# 	layer3.1.bn_a1.bias
# 	layer3.1.bn_a1.running_mean
# 	layer3.1.bn_a1.running_var
# 	layer3.1.bn_a1.num_batches_tracked
# 	layer3.1.conv_a2.weight
# 	layer3.1.bn_a2.weight
# 	layer3.1.bn_a2.bias
# 	layer3.1.bn_a2.running_mean
# 	layer3.1.bn_a2.running_var
# 	layer3.1.bn_a2.num_batches_tracked
# 	layer3.1.conv_b1.weight
# 	layer3.1.bn_b1.weight
# 	layer3.1.bn_b1.bias
# 	layer3.1.bn_b1.running_mean
# 	layer3.1.bn_b1.running_var
# 	layer3.1.bn_b1.num_batches_tracked
# 	layer3.1.conv_b2.weight
# 	layer3.1.bn_b2.weight
# 	layer3.1.bn_b2.bias
# 	layer3.1.bn_b2.running_mean
# 	layer3.1.bn_b2.running_var
# 	layer3.1.bn_b2.num_batches_tracked
# 	layer3.2.conv_a1.weight
# 	layer3.2.bn_a1.weight
# 	layer3.2.bn_a1.bias
# 	layer3.2.bn_a1.running_mean
# 	layer3.2.bn_a1.running_var
# 	layer3.2.bn_a1.num_batches_tracked
# 	layer3.2.conv_a2.weight
# 	layer3.2.bn_a2.weight
# 	layer3.2.bn_a2.bias
# 	layer3.2.bn_a2.running_mean
# 	layer3.2.bn_a2.running_var
# 	layer3.2.bn_a2.num_batches_tracked
# 	layer3.2.conv_b1.weight
# 	layer3.2.bn_b1.weight
# 	layer3.2.bn_b1.bias
# 	layer3.2.bn_b1.running_mean
# 	layer3.2.bn_b1.running_var
# 	layer3.2.bn_b1.num_batches_tracked
# 	layer3.2.conv_b2.weight
# 	layer3.2.bn_b2.weight
# 	layer3.2.bn_b2.bias
# 	layer3.2.bn_b2.running_mean
# 	layer3.2.bn_b2.running_var
# 	layer3.2.bn_b2.num_batches_tracked
# 	layer3.3.conv_a1.weight
# 	layer3.3.bn_a1.weight
# 	layer3.3.bn_a1.bias
# 	layer3.3.bn_a1.running_mean
# 	layer3.3.bn_a1.running_var
# 	layer3.3.bn_a1.num_batches_tracked
# 	layer3.3.conv_a2.weight
# 	layer3.3.bn_a2.weight
# 	layer3.3.bn_a2.bias
# 	layer3.3.bn_a2.running_mean
# 	layer3.3.bn_a2.running_var
# 	layer3.3.bn_a2.num_batches_tracked
# 	layer3.3.conv_b1.weight
# 	layer3.3.bn_b1.weight
# 	layer3.3.bn_b1.bias
# 	layer3.3.bn_b1.running_mean
# 	layer3.3.bn_b1.running_var
# 	layer3.3.bn_b1.num_batches_tracked
# 	layer3.3.conv_b2.weight
# 	layer3.3.bn_b2.weight
# 	layer3.3.bn_b2.bias
# 	layer3.3.bn_b2.running_mean
# 	layer3.3.bn_b2.running_var
# 	layer3.3.bn_b2.num_batches_tracked
# 	fc1.weight
# 	fc1.bias
# 	fc2.weight
# 	fc2.bias
# conv1.weight have been loaded correctly in current model.
# layer1.0.conv_a1.weight have been loaded correctly in current model.
# layer1.0.bn_a1.weight have been loaded correctly in current model.
# layer1.0.bn_a1.bias have been loaded correctly in current model.
# layer1.0.bn_a1.running_mean have been loaded correctly in current model.
# layer1.0.bn_a1.running_var have been loaded correctly in current model.
# layer1.0.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer1.0.conv_a2.weight have been loaded correctly in current model.
# layer1.0.bn_a2.weight have been loaded correctly in current model.
# layer1.0.bn_a2.bias have been loaded correctly in current model.
# layer1.0.bn_a2.running_mean have been loaded correctly in current model.
# layer1.0.bn_a2.running_var have been loaded correctly in current model.
# layer1.0.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer1.0.conv_b1.weight have been loaded correctly in current model.
# layer1.0.bn_b1.weight have been loaded correctly in current model.
# layer1.0.bn_b1.bias have been loaded correctly in current model.
# layer1.0.bn_b1.running_mean have been loaded correctly in current model.
# layer1.0.bn_b1.running_var have been loaded correctly in current model.
# layer1.0.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer1.0.conv_b2.weight have been loaded correctly in current model.
# layer1.0.bn_b2.weight have been loaded correctly in current model.
# layer1.0.bn_b2.bias have been loaded correctly in current model.
# layer1.0.bn_b2.running_mean have been loaded correctly in current model.
# layer1.0.bn_b2.running_var have been loaded correctly in current model.
# layer1.0.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer1.0.downsample.0.weight have been loaded correctly in current model.
# layer1.0.downsample.1.weight have been loaded correctly in current model.
# layer1.0.downsample.1.bias have been loaded correctly in current model.
# layer1.0.downsample.1.running_mean have been loaded correctly in current model.
# layer1.0.downsample.1.running_var have been loaded correctly in current model.
# layer1.0.downsample.1.num_batches_tracked have been loaded correctly in current model.
# layer1.1.conv_a1.weight have been loaded correctly in current model.
# layer1.1.bn_a1.weight have been loaded correctly in current model.
# layer1.1.bn_a1.bias have been loaded correctly in current model.
# layer1.1.bn_a1.running_mean have been loaded correctly in current model.
# layer1.1.bn_a1.running_var have been loaded correctly in current model.
# layer1.1.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer1.1.conv_a2.weight have been loaded correctly in current model.
# layer1.1.bn_a2.weight have been loaded correctly in current model.
# layer1.1.bn_a2.bias have been loaded correctly in current model.
# layer1.1.bn_a2.running_mean have been loaded correctly in current model.
# layer1.1.bn_a2.running_var have been loaded correctly in current model.
# layer1.1.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer1.1.conv_b1.weight have been loaded correctly in current model.
# layer1.1.bn_b1.weight have been loaded correctly in current model.
# layer1.1.bn_b1.bias have been loaded correctly in current model.
# layer1.1.bn_b1.running_mean have been loaded correctly in current model.
# layer1.1.bn_b1.running_var have been loaded correctly in current model.
# layer1.1.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer1.1.conv_b2.weight have been loaded correctly in current model.
# layer1.1.bn_b2.weight have been loaded correctly in current model.
# layer1.1.bn_b2.bias have been loaded correctly in current model.
# layer1.1.bn_b2.running_mean have been loaded correctly in current model.
# layer1.1.bn_b2.running_var have been loaded correctly in current model.
# layer1.1.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer1.2.conv_a1.weight have been loaded correctly in current model.
# layer1.2.bn_a1.weight have been loaded correctly in current model.
# layer1.2.bn_a1.bias have been loaded correctly in current model.
# layer1.2.bn_a1.running_mean have been loaded correctly in current model.
# layer1.2.bn_a1.running_var have been loaded correctly in current model.
# layer1.2.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer1.2.conv_a2.weight have been loaded correctly in current model.
# layer1.2.bn_a2.weight have been loaded correctly in current model.
# layer1.2.bn_a2.bias have been loaded correctly in current model.
# layer1.2.bn_a2.running_mean have been loaded correctly in current model.
# layer1.2.bn_a2.running_var have been loaded correctly in current model.
# layer1.2.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer1.2.conv_b1.weight have been loaded correctly in current model.
# layer1.2.bn_b1.weight have been loaded correctly in current model.
# layer1.2.bn_b1.bias have been loaded correctly in current model.
# layer1.2.bn_b1.running_mean have been loaded correctly in current model.
# layer1.2.bn_b1.running_var have been loaded correctly in current model.
# layer1.2.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer1.2.conv_b2.weight have been loaded correctly in current model.
# layer1.2.bn_b2.weight have been loaded correctly in current model.
# layer1.2.bn_b2.bias have been loaded correctly in current model.
# layer1.2.bn_b2.running_mean have been loaded correctly in current model.
# layer1.2.bn_b2.running_var have been loaded correctly in current model.
# layer1.2.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer1.3.conv_a1.weight have been loaded correctly in current model.
# layer1.3.bn_a1.weight have been loaded correctly in current model.
# layer1.3.bn_a1.bias have been loaded correctly in current model.
# layer1.3.bn_a1.running_mean have been loaded correctly in current model.
# layer1.3.bn_a1.running_var have been loaded correctly in current model.
# layer1.3.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer1.3.conv_a2.weight have been loaded correctly in current model.
# layer1.3.bn_a2.weight have been loaded correctly in current model.
# layer1.3.bn_a2.bias have been loaded correctly in current model.
# layer1.3.bn_a2.running_mean have been loaded correctly in current model.
# layer1.3.bn_a2.running_var have been loaded correctly in current model.
# layer1.3.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer1.3.conv_b1.weight have been loaded correctly in current model.
# layer1.3.bn_b1.weight have been loaded correctly in current model.
# layer1.3.bn_b1.bias have been loaded correctly in current model.
# layer1.3.bn_b1.running_mean have been loaded correctly in current model.
# layer1.3.bn_b1.running_var have been loaded correctly in current model.
# layer1.3.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer1.3.conv_b2.weight have been loaded correctly in current model.
# layer1.3.bn_b2.weight have been loaded correctly in current model.
# layer1.3.bn_b2.bias have been loaded correctly in current model.
# layer1.3.bn_b2.running_mean have been loaded correctly in current model.
# layer1.3.bn_b2.running_var have been loaded correctly in current model.
# layer1.3.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer2.0.conv_a1.weight have been loaded correctly in current model.
# layer2.0.bn_a1.weight have been loaded correctly in current model.
# layer2.0.bn_a1.bias have been loaded correctly in current model.
# layer2.0.bn_a1.running_mean have been loaded correctly in current model.
# layer2.0.bn_a1.running_var have been loaded correctly in current model.
# layer2.0.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer2.0.conv_a2.weight have been loaded correctly in current model.
# layer2.0.bn_a2.weight have been loaded correctly in current model.
# layer2.0.bn_a2.bias have been loaded correctly in current model.
# layer2.0.bn_a2.running_mean have been loaded correctly in current model.
# layer2.0.bn_a2.running_var have been loaded correctly in current model.
# layer2.0.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer2.0.conv_b1.weight have been loaded correctly in current model.
# layer2.0.bn_b1.weight have been loaded correctly in current model.
# layer2.0.bn_b1.bias have been loaded correctly in current model.
# layer2.0.bn_b1.running_mean have been loaded correctly in current model.
# layer2.0.bn_b1.running_var have been loaded correctly in current model.
# layer2.0.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer2.0.conv_b2.weight have been loaded correctly in current model.
# layer2.0.bn_b2.weight have been loaded correctly in current model.
# layer2.0.bn_b2.bias have been loaded correctly in current model.
# layer2.0.bn_b2.running_mean have been loaded correctly in current model.
# layer2.0.bn_b2.running_var have been loaded correctly in current model.
# layer2.0.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer2.0.downsample.conv.weight have been loaded correctly in current model.
# layer2.0.downsample.conv.bias have been loaded correctly in current model.
# layer2.0.downsample.bn.weight have been loaded correctly in current model.
# layer2.0.downsample.bn.bias have been loaded correctly in current model.
# layer2.0.downsample.bn.running_mean have been loaded correctly in current model.
# layer2.0.downsample.bn.running_var have been loaded correctly in current model.
# layer2.0.downsample.bn.num_batches_tracked have been loaded correctly in current model.
# layer2.1.conv_a1.weight have been loaded correctly in current model.
# layer2.1.bn_a1.weight have been loaded correctly in current model.
# layer2.1.bn_a1.bias have been loaded correctly in current model.
# layer2.1.bn_a1.running_mean have been loaded correctly in current model.
# layer2.1.bn_a1.running_var have been loaded correctly in current model.
# layer2.1.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer2.1.conv_a2.weight have been loaded correctly in current model.
# layer2.1.bn_a2.weight have been loaded correctly in current model.
# layer2.1.bn_a2.bias have been loaded correctly in current model.
# layer2.1.bn_a2.running_mean have been loaded correctly in current model.
# layer2.1.bn_a2.running_var have been loaded correctly in current model.
# layer2.1.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer2.1.conv_b1.weight have been loaded correctly in current model.
# layer2.1.bn_b1.weight have been loaded correctly in current model.
# layer2.1.bn_b1.bias have been loaded correctly in current model.
# layer2.1.bn_b1.running_mean have been loaded correctly in current model.
# layer2.1.bn_b1.running_var have been loaded correctly in current model.
# layer2.1.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer2.1.conv_b2.weight have been loaded correctly in current model.
# layer2.1.bn_b2.weight have been loaded correctly in current model.
# layer2.1.bn_b2.bias have been loaded correctly in current model.
# layer2.1.bn_b2.running_mean have been loaded correctly in current model.
# layer2.1.bn_b2.running_var have been loaded correctly in current model.
# layer2.1.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer2.2.conv_a1.weight have been loaded correctly in current model.
# layer2.2.bn_a1.weight have been loaded correctly in current model.
# layer2.2.bn_a1.bias have been loaded correctly in current model.
# layer2.2.bn_a1.running_mean have been loaded correctly in current model.
# layer2.2.bn_a1.running_var have been loaded correctly in current model.
# layer2.2.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer2.2.conv_a2.weight have been loaded correctly in current model.
# layer2.2.bn_a2.weight have been loaded correctly in current model.
# layer2.2.bn_a2.bias have been loaded correctly in current model.
# layer2.2.bn_a2.running_mean have been loaded correctly in current model.
# layer2.2.bn_a2.running_var have been loaded correctly in current model.
# layer2.2.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer2.2.conv_b1.weight have been loaded correctly in current model.
# layer2.2.bn_b1.weight have been loaded correctly in current model.
# layer2.2.bn_b1.bias have been loaded correctly in current model.
# layer2.2.bn_b1.running_mean have been loaded correctly in current model.
# layer2.2.bn_b1.running_var have been loaded correctly in current model.
# layer2.2.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer2.2.conv_b2.weight have been loaded correctly in current model.
# layer2.2.bn_b2.weight have been loaded correctly in current model.
# layer2.2.bn_b2.bias have been loaded correctly in current model.
# layer2.2.bn_b2.running_mean have been loaded correctly in current model.
# layer2.2.bn_b2.running_var have been loaded correctly in current model.
# layer2.2.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer2.3.conv_a1.weight have been loaded correctly in current model.
# layer2.3.bn_a1.weight have been loaded correctly in current model.
# layer2.3.bn_a1.bias have been loaded correctly in current model.
# layer2.3.bn_a1.running_mean have been loaded correctly in current model.
# layer2.3.bn_a1.running_var have been loaded correctly in current model.
# layer2.3.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer2.3.conv_a2.weight have been loaded correctly in current model.
# layer2.3.bn_a2.weight have been loaded correctly in current model.
# layer2.3.bn_a2.bias have been loaded correctly in current model.
# layer2.3.bn_a2.running_mean have been loaded correctly in current model.
# layer2.3.bn_a2.running_var have been loaded correctly in current model.
# layer2.3.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer2.3.conv_b1.weight have been loaded correctly in current model.
# layer2.3.bn_b1.weight have been loaded correctly in current model.
# layer2.3.bn_b1.bias have been loaded correctly in current model.
# layer2.3.bn_b1.running_mean have been loaded correctly in current model.
# layer2.3.bn_b1.running_var have been loaded correctly in current model.
# layer2.3.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer2.3.conv_b2.weight have been loaded correctly in current model.
# layer2.3.bn_b2.weight have been loaded correctly in current model.
# layer2.3.bn_b2.bias have been loaded correctly in current model.
# layer2.3.bn_b2.running_mean have been loaded correctly in current model.
# layer2.3.bn_b2.running_var have been loaded correctly in current model.
# layer2.3.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer3.0.conv_a1.weight have been loaded correctly in current model.
# layer3.0.bn_a1.weight have been loaded correctly in current model.
# layer3.0.bn_a1.bias have been loaded correctly in current model.
# layer3.0.bn_a1.running_mean have been loaded correctly in current model.
# layer3.0.bn_a1.running_var have been loaded correctly in current model.
# layer3.0.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer3.0.conv_a2.weight have been loaded correctly in current model.
# layer3.0.bn_a2.weight have been loaded correctly in current model.
# layer3.0.bn_a2.bias have been loaded correctly in current model.
# layer3.0.bn_a2.running_mean have been loaded correctly in current model.
# layer3.0.bn_a2.running_var have been loaded correctly in current model.
# layer3.0.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer3.0.conv_b1.weight have been loaded correctly in current model.
# layer3.0.bn_b1.weight have been loaded correctly in current model.
# layer3.0.bn_b1.bias have been loaded correctly in current model.
# layer3.0.bn_b1.running_mean have been loaded correctly in current model.
# layer3.0.bn_b1.running_var have been loaded correctly in current model.
# layer3.0.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer3.0.conv_b2.weight have been loaded correctly in current model.
# layer3.0.bn_b2.weight have been loaded correctly in current model.
# layer3.0.bn_b2.bias have been loaded correctly in current model.
# layer3.0.bn_b2.running_mean have been loaded correctly in current model.
# layer3.0.bn_b2.running_var have been loaded correctly in current model.
# layer3.0.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer3.0.downsample.conv.weight have been loaded correctly in current model.
# layer3.0.downsample.conv.bias have been loaded correctly in current model.
# layer3.0.downsample.bn.weight have been loaded correctly in current model.
# layer3.0.downsample.bn.bias have been loaded correctly in current model.
# layer3.0.downsample.bn.running_mean have been loaded correctly in current model.
# layer3.0.downsample.bn.running_var have been loaded correctly in current model.
# layer3.0.downsample.bn.num_batches_tracked have been loaded correctly in current model.
# layer3.1.conv_a1.weight have been loaded correctly in current model.
# layer3.1.bn_a1.weight have been loaded correctly in current model.
# layer3.1.bn_a1.bias have been loaded correctly in current model.
# layer3.1.bn_a1.running_mean have been loaded correctly in current model.
# layer3.1.bn_a1.running_var have been loaded correctly in current model.
# layer3.1.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer3.1.conv_a2.weight have been loaded correctly in current model.
# layer3.1.bn_a2.weight have been loaded correctly in current model.
# layer3.1.bn_a2.bias have been loaded correctly in current model.
# layer3.1.bn_a2.running_mean have been loaded correctly in current model.
# layer3.1.bn_a2.running_var have been loaded correctly in current model.
# layer3.1.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer3.1.conv_b1.weight have been loaded correctly in current model.
# layer3.1.bn_b1.weight have been loaded correctly in current model.
# layer3.1.bn_b1.bias have been loaded correctly in current model.
# layer3.1.bn_b1.running_mean have been loaded correctly in current model.
# layer3.1.bn_b1.running_var have been loaded correctly in current model.
# layer3.1.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer3.1.conv_b2.weight have been loaded correctly in current model.
# layer3.1.bn_b2.weight have been loaded correctly in current model.
# layer3.1.bn_b2.bias have been loaded correctly in current model.
# layer3.1.bn_b2.running_mean have been loaded correctly in current model.
# layer3.1.bn_b2.running_var have been loaded correctly in current model.
# layer3.1.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer3.2.conv_a1.weight have been loaded correctly in current model.
# layer3.2.bn_a1.weight have been loaded correctly in current model.
# layer3.2.bn_a1.bias have been loaded correctly in current model.
# layer3.2.bn_a1.running_mean have been loaded correctly in current model.
# layer3.2.bn_a1.running_var have been loaded correctly in current model.
# layer3.2.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer3.2.conv_a2.weight have been loaded correctly in current model.
# layer3.2.bn_a2.weight have been loaded correctly in current model.
# layer3.2.bn_a2.bias have been loaded correctly in current model.
# layer3.2.bn_a2.running_mean have been loaded correctly in current model.
# layer3.2.bn_a2.running_var have been loaded correctly in current model.
# layer3.2.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer3.2.conv_b1.weight have been loaded correctly in current model.
# layer3.2.bn_b1.weight have been loaded correctly in current model.
# layer3.2.bn_b1.bias have been loaded correctly in current model.
# layer3.2.bn_b1.running_mean have been loaded correctly in current model.
# layer3.2.bn_b1.running_var have been loaded correctly in current model.
# layer3.2.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer3.2.conv_b2.weight have been loaded correctly in current model.
# layer3.2.bn_b2.weight have been loaded correctly in current model.
# layer3.2.bn_b2.bias have been loaded correctly in current model.
# layer3.2.bn_b2.running_mean have been loaded correctly in current model.
# layer3.2.bn_b2.running_var have been loaded correctly in current model.
# layer3.2.bn_b2.num_batches_tracked have been loaded correctly in current model.
# layer3.3.conv_a1.weight have been loaded correctly in current model.
# layer3.3.bn_a1.weight have been loaded correctly in current model.
# layer3.3.bn_a1.bias have been loaded correctly in current model.
# layer3.3.bn_a1.running_mean have been loaded correctly in current model.
# layer3.3.bn_a1.running_var have been loaded correctly in current model.
# layer3.3.bn_a1.num_batches_tracked have been loaded correctly in current model.
# layer3.3.conv_a2.weight have been loaded correctly in current model.
# layer3.3.bn_a2.weight have been loaded correctly in current model.
# layer3.3.bn_a2.bias have been loaded correctly in current model.
# layer3.3.bn_a2.running_mean have been loaded correctly in current model.
# layer3.3.bn_a2.running_var have been loaded correctly in current model.
# layer3.3.bn_a2.num_batches_tracked have been loaded correctly in current model.
# layer3.3.conv_b1.weight have been loaded correctly in current model.
# layer3.3.bn_b1.weight have been loaded correctly in current model.
# layer3.3.bn_b1.bias have been loaded correctly in current model.
# layer3.3.bn_b1.running_mean have been loaded correctly in current model.
# layer3.3.bn_b1.running_var have been loaded correctly in current model.
# layer3.3.bn_b1.num_batches_tracked have been loaded correctly in current model.
# layer3.3.conv_b2.weight have been loaded correctly in current model.
# layer3.3.bn_b2.weight have been loaded correctly in current model.
# layer3.3.bn_b2.bias have been loaded correctly in current model.
# layer3.3.bn_b2.running_mean have been loaded correctly in current model.
# layer3.3.bn_b2.running_var have been loaded correctly in current model.
# layer3.3.bn_b2.num_batches_tracked have been loaded correctly in current model.
# fc1.weight have been loaded correctly in current model.
# fc1.bias have been loaded correctly in current model.
# fc2.weight have been loaded correctly in current model.
# fc2.bias have been loaded correctly in current model.
# n parameters: 26959616

# %%
data_loader_val = load_data('/scratch/ehd255/ssl_data_96', 32, split='val')

# %%
evaluate(model, data_loader_val, device, 'Validation')
# Out:
# Evaluating Validation set...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fc832b8cec9f> in <module>
# ----> 1 evaluate(model, data_loader_val, device, 'Validation')
#
# <ipython-input-2-9594350c1609> in evaluate(model, data_loader, device, split, top_k)
#      23     n_correct_top_k = 0
#      24
# ---> 25     for img, target in data_loader:
#      26         img, target = img.to(device), target.to(device)
#      27         batch_size = img.size(0)
#
# /scratch/jtb470/SemiSupervisedLearning/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /scratch/jtb470/SemiSupervisedLearning/env/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /scratch/jtb470/SemiSupervisedLearning/env/lib/python3.6/site-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     132         sample = self.loader(path)
#     133         if self.transform is not None:
# --> 134             sample = self.transform(sample)
#     135         if self.target_transform is not None:
#     136             target = self.target_transform(target)
#
# /scratch/jtb470/SemiSupervisedLearning/env/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# /scratch/jtb470/SemiSupervisedLearning/env/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      89             Tensor: Converted image.
#      90         """
# ---> 91         return F.to_tensor(pic)
#      92
#      93     def __repr__(self):
#
# /scratch/jtb470/SemiSupervisedLearning/env/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      90     img = img.transpose(0, 1).transpose(0, 2).contiguous()
#      91     if isinstance(img, torch.ByteTensor):
# ---> 92         return img.float().div(255)
#      93     else:
#      94         return img
#
# KeyboardInterrupt:
